# %%
"""
===========================================================
Using PyPARRM to filter out stimulation artefacts from data
===========================================================

This example demonstrates how the PARRM algorithm :footcite:`DastinEtAl2021`
can be used to identify and remove stimulation artefacts from
electrophysiological data in the PyPARRM package.
"""

import numpy as np
from matplotlib import pyplot as plt

import sys
import sys
sys.path.append('../../../../tool_code/python_tool_code/function/') # "~~/tool_code/plot/" (상대 경로)
sys.path.append('../../../../tool_code/python_tool_code/frequency_dataset_generation/')

from DataPlot import Data_Load_Plot, Result_Plot, Result_Plot_paper, Loss_Plot
from Scaling import time_scaling, time_inv_scaling
from FFT_func import FFT

sys.path.append('../../../../existing_SAC/PARRM/PyPARRM-main/src/pyparrm')

from parrm import PARRM
from _utils._power import compute_psd

# fpath='../../../../data/synthetic_data/'
fpath = "../../../../data/synthetic_data/evaluation_data/"

Contaminated = np.load(fpath + "contaminated_by_realistic" + ".npy")
Clean = np.load(fpath + "clean_data" + ".npy")
# Contaminated = Contaminated[0:10]
# Clean = Clean[0:10]

# %%
fs = 2000  # Hz
artefact_freq = 125  # Hz

winTime = 0.99
skipTime = winTime / 30
perDist = 0.01

winSize = int(fs*winTime)
skipSize = int(fs*skipTime)
winDir = "both"

print(
    f"`data` has shape: ({Contaminated.shape[0]} channel, "
    f"{Contaminated.shape[1]} timepoints)\n"
    f"`data` duration: {Contaminated.shape[1] / fs :.2f} seconds"
)
# Out:
# `data` has shape: (2000 channel, 4000 timepoints)
# `data` duration: 2.00 seconds

# %%
# parrm = PARRM(
#     data=Contaminated,
#     sampling_freq=fs,
#     artefact_freq=artefact_freq,
#     verbose=False,  # silenced to reduce pqdm output clutter
# )
# parrm.find_period()

# print(f"Estimated artefact period: {parrm.period :.4f}")

# parrm.create_filter(
#     filter_half_width=winSize,
#     omit_n_samples=skipSize,
#     filter_direction="both",
#     period_half_width=perDist,
# )
# filtered_data = parrm.filter_data()  # other data to filter can be given here

# %%
## 기존 ##
parrmed = []

for i in range(Contaminated.shape[0]):
    parrm = PARRM(
        data=Contaminated[i].reshape(1, -1),
        sampling_freq=fs,
        artefact_freq=artefact_freq,
        verbose=False,  # silenced to reduce pqdm output clutter
    )

    parrm.find_period()

    print(f"Sample : {i} | Estimated artefact period: {parrm.period :.4f}")

    parrm.create_filter(
        filter_half_width=winSize,
        omit_n_samples=skipSize,
        filter_direction=winDir,
        period_half_width=perDist,
    )
    parrmed_data = parrm.filter_data()  # other data to filter can be given here
    parrmed.append(parrmed_data)
# Out:
# Sample : 0 | Estimated artefact period: 16.0001
# Sample : 1 | Estimated artefact period: 16.0002
# Sample : 2 | Estimated artefact period: 16.0001
# Sample : 3 | Estimated artefact period: 16.0001
# Sample : 4 | Estimated artefact period: 16.0002
# Sample : 5 | Estimated artefact period: 16.0001
# Sample : 6 | Estimated artefact period: 16.0002
# Sample : 7 | Estimated artefact period: 16.0002
# Sample : 8 | Estimated artefact period: 16.0002
# Sample : 9 | Estimated artefact period: 16.0001
# Sample : 10 | Estimated artefact period: 16.0001
# Sample : 11 | Estimated artefact period: 16.0001
# Sample : 12 | Estimated artefact period: 16.0002
# Sample : 13 | Estimated artefact period: 16.0002
# Sample : 14 | Estimated artefact period: 16.0001
# Sample : 15 | Estimated artefact period: 16.0001
# Sample : 16 | Estimated artefact period: 16.0002
# Sample : 17 | Estimated artefact period: 16.0002
# Sample : 18 | Estimated artefact period: 16.0002
# Sample : 19 | Estimated artefact period: 16.0001
# Sample : 20 | Estimated artefact period: 16.0002
# Sample : 21 | Estimated artefact period: 16.0001
# Sample : 22 | Estimated artefact period: 16.0002
# Sample : 23 | Estimated artefact period: 16.0002
# Sample : 24 | Estimated artefact period: 16.0002
# Sample : 25 | Estimated artefact period: 16.0001
# Sample : 26 | Estimated artefact period: 16.0002
# Sample : 27 | Estimated artefact period: 16.0002
# Sample : 28 | Estimated artefact period: 16.0002
# Sample : 29 | Estimated artefact period: 16.0001
# Sample : 30 | Estimated artefact period: 16.0002
# Sample : 31 | Estimated artefact period: 16.0002
# Sample : 32 | Estimated artefact period: 16.0001
# Sample : 33 | Estimated artefact period: 16.0001
# Sample : 34 | Estimated artefact period: 16.0002
# Sample : 35 | Estimated artefact period: 16.0001
# Sample : 36 | Estimated artefact period: 16.0002
# Sample : 37 | Estimated artefact period: 16.0001
# Sample : 38 | Estimated artefact period: 16.0001
# Sample : 39 | Estimated artefact period: 16.0002
# Sample : 40 | Estimated artefact period: 16.0002
# Sample : 41 | Estimated artefact period: 16.0002
# Sample : 42 | Estimated artefact period: 16.0001
# Sample : 43 | Estimated artefact period: 16.0001
# Sample : 44 | Estimated artefact period: 16.0002
# Sample : 45 | Estimated artefact period: 16.0002
# Sample : 46 | Estimated artefact period: 16.0001
# Sample : 47 | Estimated artefact period: 16.0002
# Sample : 48 | Estimated artefact period: 16.0002
# Sample : 49 | Estimated artefact period: 16.0002
# Sample : 50 | Estimated artefact period: 16.0001
# Sample : 51 | Estimated artefact period: 16.0002
# Sample : 52 | Estimated artefact period: 16.0002
# Sample : 53 | Estimated artefact period: 16.0001
# Sample : 54 | Estimated artefact period: 16.0002
# Sample : 55 | Estimated artefact period: 16.0002
# Sample : 56 | Estimated artefact period: 16.0001
# Sample : 57 | Estimated artefact period: 16.0001
# Sample : 58 | Estimated artefact period: 16.0001
# Sample : 59 | Estimated artefact period: 16.0001
# Sample : 60 | Estimated artefact period: 16.0002
# Sample : 61 | Estimated artefact period: 16.0002
# Sample : 62 | Estimated artefact period: 16.0002
# Sample : 63 | Estimated artefact period: 16.0002
# Sample : 64 | Estimated artefact period: 16.0002
# Sample : 65 | Estimated artefact period: 16.0002
# Sample : 66 | Estimated artefact period: 16.0001
# Sample : 67 | Estimated artefact period: 16.0001
# Sample : 68 | Estimated artefact period: 16.0002
# Sample : 69 | Estimated artefact period: 16.0001
# Sample : 70 | Estimated artefact period: 16.0001
# Sample : 71 | Estimated artefact period: 16.0002
# Sample : 72 | Estimated artefact period: 16.0001
# Sample : 73 | Estimated artefact period: 16.0002
# Sample : 74 | Estimated artefact period: 16.0002
# Sample : 75 | Estimated artefact period: 16.0002
# Sample : 76 | Estimated artefact period: 16.0001
# Sample : 77 | Estimated artefact period: 16.0002
# Sample : 78 | Estimated artefact period: 16.0002
# Sample : 79 | Estimated artefact period: 16.0002
# Sample : 80 | Estimated artefact period: 16.0001
# Sample : 81 | Estimated artefact period: 16.0001
# Sample : 82 | Estimated artefact period: 16.0001
# Sample : 83 | Estimated artefact period: 16.0001
# Sample : 84 | Estimated artefact period: 16.0002
# Sample : 85 | Estimated artefact period: 16.0002
# Sample : 86 | Estimated artefact period: 16.0001
# Sample : 87 | Estimated artefact period: 16.0001
# Sample : 88 | Estimated artefact period: 16.0002
# Sample : 89 | Estimated artefact period: 16.0002
# Sample : 90 | Estimated artefact period: 16.0002
# Sample : 91 | Estimated artefact period: 16.0002
# Sample : 92 | Estimated artefact period: 16.0001
# Sample : 93 | Estimated artefact period: 16.0002
# Sample : 94 | Estimated artefact period: 16.0001
# Sample : 95 | Estimated artefact period: 16.0001
# Sample : 96 | Estimated artefact period: 16.0001
# Sample : 97 | Estimated artefact period: 16.0001
# Sample : 98 | Estimated artefact period: 16.0001
# Sample : 99 | Estimated artefact period: 16.0002
# Sample : 100 | Estimated artefact period: 16.0002
# Sample : 101 | Estimated artefact period: 16.0002
# Sample : 102 | Estimated artefact period: 16.0001
# Sample : 103 | Estimated artefact period: 16.0001
# Sample : 104 | Estimated artefact period: 16.0002
# Sample : 105 | Estimated artefact period: 16.0001
# Sample : 106 | Estimated artefact period: 16.0001
# Sample : 107 | Estimated artefact period: 16.0002
# Sample : 108 | Estimated artefact period: 16.0002
# Sample : 109 | Estimated artefact period: 16.0002
# Sample : 110 | Estimated artefact period: 16.0001
# Sample : 111 | Estimated artefact period: 16.0002
# Sample : 112 | Estimated artefact period: 16.0002
# Sample : 113 | Estimated artefact period: 16.0002
# Sample : 114 | Estimated artefact period: 16.0002
# Sample : 115 | Estimated artefact period: 16.0002
# Sample : 116 | Estimated artefact period: 16.0002
# Sample : 117 | Estimated artefact period: 16.0001
# Sample : 118 | Estimated artefact period: 16.0002
# Sample : 119 | Estimated artefact period: 16.0002
# Sample : 120 | Estimated artefact period: 16.0001
# Sample : 121 | Estimated artefact period: 16.0002
# Sample : 122 | Estimated artefact period: 16.0002
# Sample : 123 | Estimated artefact period: 16.0001
# Sample : 124 | Estimated artefact period: 16.0002
# Sample : 125 | Estimated artefact period: 16.0002
# Sample : 126 | Estimated artefact period: 16.0002
# Sample : 127 | Estimated artefact period: 16.0002
# Sample : 128 | Estimated artefact period: 16.0002
# Sample : 129 | Estimated artefact period: 16.0002
# Sample : 130 | Estimated artefact period: 16.0002
# Sample : 131 | Estimated artefact period: 16.0002
# Sample : 132 | Estimated artefact period: 16.0001
# Sample : 133 | Estimated artefact period: 16.0001
# Sample : 134 | Estimated artefact period: 16.0002
# Sample : 135 | Estimated artefact period: 16.0001
# Sample : 136 | Estimated artefact period: 16.0001
# Sample : 137 | Estimated artefact period: 16.0002
# Sample : 138 | Estimated artefact period: 16.0001
# Sample : 139 | Estimated artefact period: 16.0001
# Sample : 140 | Estimated artefact period: 16.0001
# Sample : 141 | Estimated artefact period: 16.0002
# Sample : 142 | Estimated artefact period: 16.0002
# Sample : 143 | Estimated artefact period: 16.0002
# Sample : 144 | Estimated artefact period: 16.0002
# Sample : 145 | Estimated artefact period: 16.0002
# Sample : 146 | Estimated artefact period: 16.0002
# Sample : 147 | Estimated artefact period: 16.0001
# Sample : 148 | Estimated artefact period: 16.0001
# Sample : 149 | Estimated artefact period: 16.0002
# Sample : 150 | Estimated artefact period: 16.0001
# Sample : 151 | Estimated artefact period: 16.0001
# Sample : 152 | Estimated artefact period: 16.0001
# Sample : 153 | Estimated artefact period: 16.0002
# Sample : 154 | Estimated artefact period: 16.0002
# Sample : 155 | Estimated artefact period: 16.0002
# Sample : 156 | Estimated artefact period: 16.0002
# Sample : 157 | Estimated artefact period: 16.0002
# Sample : 158 | Estimated artefact period: 16.0002
# Sample : 159 | Estimated artefact period: 16.0001
# Sample : 160 | Estimated artefact period: 16.0001
# Sample : 161 | Estimated artefact period: 16.0001
# Sample : 162 | Estimated artefact period: 16.0002
# Sample : 163 | Estimated artefact period: 16.0002
# Sample : 164 | Estimated artefact period: 16.0002
# Sample : 165 | Estimated artefact period: 16.0001
# Sample : 166 | Estimated artefact period: 16.0001
# Sample : 167 | Estimated artefact period: 16.0002
# Sample : 168 | Estimated artefact period: 16.0002
# Sample : 169 | Estimated artefact period: 16.0001
# Sample : 170 | Estimated artefact period: 16.0002
# Sample : 171 | Estimated artefact period: 16.0002
# Sample : 172 | Estimated artefact period: 16.0002
# Sample : 173 | Estimated artefact period: 16.0002
# Sample : 174 | Estimated artefact period: 16.0002
# Sample : 175 | Estimated artefact period: 16.0001
# Sample : 176 | Estimated artefact period: 16.0002
# Sample : 177 | Estimated artefact period: 16.0001
# Sample : 178 | Estimated artefact period: 16.0002
# Sample : 179 | Estimated artefact period: 16.0001
# Sample : 180 | Estimated artefact period: 16.0002
# Sample : 181 | Estimated artefact period: 16.0002
# Sample : 182 | Estimated artefact period: 16.0001
# Sample : 183 | Estimated artefact period: 16.0002
# Sample : 184 | Estimated artefact period: 16.0001
# Sample : 185 | Estimated artefact period: 16.0001
# Sample : 186 | Estimated artefact period: 16.0001
# Sample : 187 | Estimated artefact period: 16.0001
# Sample : 188 | Estimated artefact period: 16.0001
# Sample : 189 | Estimated artefact period: 16.0001
# Sample : 190 | Estimated artefact period: 16.0001
# Sample : 191 | Estimated artefact period: 16.0001
# Sample : 192 | Estimated artefact period: 16.0002
# Sample : 193 | Estimated artefact period: 16.0002
# Sample : 194 | Estimated artefact period: 16.0001
# Sample : 195 | Estimated artefact period: 16.0002
# Sample : 196 | Estimated artefact period: 16.0001
# Sample : 197 | Estimated artefact period: 16.0001
# Sample : 198 | Estimated artefact period: 16.0002
# Sample : 199 | Estimated artefact period: 16.0002
# Sample : 200 | Estimated artefact period: 16.0002
# Sample : 201 | Estimated artefact period: 16.0002
# Sample : 202 | Estimated artefact period: 16.0002
# Sample : 203 | Estimated artefact period: 16.0001
# Sample : 204 | Estimated artefact period: 16.0001
# Sample : 205 | Estimated artefact period: 16.0002
# Sample : 206 | Estimated artefact period: 16.0001
# Sample : 207 | Estimated artefact period: 16.0001
# Sample : 208 | Estimated artefact period: 16.0002
# Sample : 209 | Estimated artefact period: 16.0001
# Sample : 210 | Estimated artefact period: 16.0001
# Sample : 211 | Estimated artefact period: 16.0001
# Sample : 212 | Estimated artefact period: 16.0002
# Sample : 213 | Estimated artefact period: 16.0002
# Sample : 214 | Estimated artefact period: 16.0002
# Sample : 215 | Estimated artefact period: 16.0001
# Sample : 216 | Estimated artefact period: 16.0002
# Sample : 217 | Estimated artefact period: 16.0001
# Sample : 218 | Estimated artefact period: 16.0001
# Sample : 219 | Estimated artefact period: 16.0001
# Sample : 220 | Estimated artefact period: 16.0001
# Sample : 221 | Estimated artefact period: 16.0001
# Sample : 222 | Estimated artefact period: 16.0001
# Sample : 223 | Estimated artefact period: 16.0001
# Sample : 224 | Estimated artefact period: 16.0002
# Sample : 225 | Estimated artefact period: 16.0001
# Sample : 226 | Estimated artefact period: 16.0001
# Sample : 227 | Estimated artefact period: 16.0002
# Sample : 228 | Estimated artefact period: 16.0002
# Sample : 229 | Estimated artefact period: 16.0002
# Sample : 230 | Estimated artefact period: 16.0001
# Sample : 231 | Estimated artefact period: 16.0002
# Sample : 232 | Estimated artefact period: 16.0002
# Sample : 233 | Estimated artefact period: 16.0001
# Sample : 234 | Estimated artefact period: 16.0002
# Sample : 235 | Estimated artefact period: 16.0001
# Sample : 236 | Estimated artefact period: 16.0002
# Sample : 237 | Estimated artefact period: 16.0001
# Sample : 238 | Estimated artefact period: 16.0001
# Sample : 239 | Estimated artefact period: 16.0002
# Sample : 240 | Estimated artefact period: 16.0001
# Sample : 241 | Estimated artefact period: 16.0001
# Sample : 242 | Estimated artefact period: 16.0001
# Sample : 243 | Estimated artefact period: 16.0001
# Sample : 244 | Estimated artefact period: 16.0002
# Sample : 245 | Estimated artefact period: 16.0001
# Sample : 246 | Estimated artefact period: 16.0001
# Sample : 247 | Estimated artefact period: 16.0001
# Sample : 248 | Estimated artefact period: 16.0001
# Sample : 249 | Estimated artefact period: 16.0002
# Sample : 250 | Estimated artefact period: 16.0001
# Sample : 251 | Estimated artefact period: 16.0002
# Sample : 252 | Estimated artefact period: 16.0002
# Sample : 253 | Estimated artefact period: 16.0001
# Sample : 254 | Estimated artefact period: 16.0002
# Sample : 255 | Estimated artefact period: 16.0002
# Sample : 256 | Estimated artefact period: 16.0001
# Sample : 257 | Estimated artefact period: 16.0002
# Sample : 258 | Estimated artefact period: 16.0001
# Sample : 259 | Estimated artefact period: 16.0001
# Sample : 260 | Estimated artefact period: 16.0001
# Sample : 261 | Estimated artefact period: 16.0002
# Sample : 262 | Estimated artefact period: 16.0001
# Sample : 263 | Estimated artefact period: 16.0001
# Sample : 264 | Estimated artefact period: 16.0002
# Sample : 265 | Estimated artefact period: 16.0002
# Sample : 266 | Estimated artefact period: 16.0002
# Sample : 267 | Estimated artefact period: 16.0002
# Sample : 268 | Estimated artefact period: 16.0001
# Sample : 269 | Estimated artefact period: 16.0002
# Sample : 270 | Estimated artefact period: 16.0002
# Sample : 271 | Estimated artefact period: 16.0001
# Sample : 272 | Estimated artefact period: 16.0001
# Sample : 273 | Estimated artefact period: 16.0001
# Sample : 274 | Estimated artefact period: 16.0002
# Sample : 275 | Estimated artefact period: 16.0001
# Sample : 276 | Estimated artefact period: 16.0002
# Sample : 277 | Estimated artefact period: 16.0001
# Sample : 278 | Estimated artefact period: 16.0002
# Sample : 279 | Estimated artefact period: 16.0002
# Sample : 280 | Estimated artefact period: 16.0001
# Sample : 281 | Estimated artefact period: 16.0002
# Sample : 282 | Estimated artefact period: 16.0001
# Sample : 283 | Estimated artefact period: 16.0002
# Sample : 284 | Estimated artefact period: 16.0001
# Sample : 285 | Estimated artefact period: 16.0002
# Sample : 286 | Estimated artefact period: 16.0002
# Sample : 287 | Estimated artefact period: 16.0002
# Sample : 288 | Estimated artefact period: 16.0002
# Sample : 289 | Estimated artefact period: 16.0002
# Sample : 290 | Estimated artefact period: 16.0002
# Sample : 291 | Estimated artefact period: 16.0001
# Sample : 292 | Estimated artefact period: 16.0002
# Sample : 293 | Estimated artefact period: 16.0001
# Sample : 294 | Estimated artefact period: 16.0001
# Sample : 295 | Estimated artefact period: 16.0001
# Sample : 296 | Estimated artefact period: 16.0002
# Sample : 297 | Estimated artefact period: 16.0001
# Sample : 298 | Estimated artefact period: 16.0002
# Sample : 299 | Estimated artefact period: 16.0001
# Sample : 300 | Estimated artefact period: 16.0001
# Sample : 301 | Estimated artefact period: 16.0001
# Sample : 302 | Estimated artefact period: 16.0001
# Sample : 303 | Estimated artefact period: 16.0001
# Sample : 304 | Estimated artefact period: 16.0001
# Sample : 305 | Estimated artefact period: 16.0001
# Sample : 306 | Estimated artefact period: 16.0001
# Sample : 307 | Estimated artefact period: 16.0001
# Sample : 308 | Estimated artefact period: 16.0001
# Sample : 309 | Estimated artefact period: 16.0001
# Sample : 310 | Estimated artefact period: 16.0002
# Sample : 311 | Estimated artefact period: 16.0001
# Sample : 312 | Estimated artefact period: 16.0002
# Sample : 313 | Estimated artefact period: 16.0001
# Sample : 314 | Estimated artefact period: 16.0001
# Sample : 315 | Estimated artefact period: 16.0002
# Sample : 316 | Estimated artefact period: 16.0002
# Sample : 317 | Estimated artefact period: 16.0002
# Sample : 318 | Estimated artefact period: 16.0001
# Sample : 319 | Estimated artefact period: 16.0001
# Sample : 320 | Estimated artefact period: 16.0001
# Sample : 321 | Estimated artefact period: 16.0002
# Sample : 322 | Estimated artefact period: 16.0001
# Sample : 323 | Estimated artefact period: 16.0002
# Sample : 324 | Estimated artefact period: 16.0001
# Sample : 325 | Estimated artefact period: 16.0002
# Sample : 326 | Estimated artefact period: 16.0001
# Sample : 327 | Estimated artefact period: 16.0001
# Sample : 328 | Estimated artefact period: 16.0001
# Sample : 329 | Estimated artefact period: 16.0001
# Sample : 330 | Estimated artefact period: 16.0001
# Sample : 331 | Estimated artefact period: 16.0001
# Sample : 332 | Estimated artefact period: 16.0001
# Sample : 333 | Estimated artefact period: 16.0001
# Sample : 334 | Estimated artefact period: 16.0002
# Sample : 335 | Estimated artefact period: 16.0001
# Sample : 336 | Estimated artefact period: 16.0001
# Sample : 337 | Estimated artefact period: 16.0001
# Sample : 338 | Estimated artefact period: 16.0002
# Sample : 339 | Estimated artefact period: 16.0002
# Sample : 340 | Estimated artefact period: 16.0002
# Sample : 341 | Estimated artefact period: 16.0001
# Sample : 342 | Estimated artefact period: 16.0002
# Sample : 343 | Estimated artefact period: 16.0002
# Sample : 344 | Estimated artefact period: 16.0001
# Sample : 345 | Estimated artefact period: 16.0001
# Sample : 346 | Estimated artefact period: 16.0002
# Sample : 347 | Estimated artefact period: 16.0001
# Sample : 348 | Estimated artefact period: 16.0002
# Sample : 349 | Estimated artefact period: 16.0002
# Sample : 350 | Estimated artefact period: 16.0002
# Sample : 351 | Estimated artefact period: 16.0001
# Sample : 352 | Estimated artefact period: 16.0002
# Sample : 353 | Estimated artefact period: 16.0002
# Sample : 354 | Estimated artefact period: 16.0002
# Sample : 355 | Estimated artefact period: 16.0001
# Sample : 356 | Estimated artefact period: 16.0002
# Sample : 357 | Estimated artefact period: 16.0002
# Sample : 358 | Estimated artefact period: 16.0002
# Sample : 359 | Estimated artefact period: 16.0002
# Sample : 360 | Estimated artefact period: 16.0001
# Sample : 361 | Estimated artefact period: 16.0002
# Sample : 362 | Estimated artefact period: 16.0001
# Sample : 363 | Estimated artefact period: 16.0002
# Sample : 364 | Estimated artefact period: 16.0002
# Sample : 365 | Estimated artefact period: 16.0001
# Sample : 366 | Estimated artefact period: 16.0001
# Sample : 367 | Estimated artefact period: 16.0001
# Sample : 368 | Estimated artefact period: 16.0001
# Sample : 369 | Estimated artefact period: 16.0002
# Sample : 370 | Estimated artefact period: 16.0002
# Sample : 371 | Estimated artefact period: 16.0002
# Sample : 372 | Estimated artefact period: 16.0001
# Sample : 373 | Estimated artefact period: 16.0002
# Sample : 374 | Estimated artefact period: 16.0002
# Sample : 375 | Estimated artefact period: 16.0002
# Sample : 376 | Estimated artefact period: 16.0002
# Sample : 377 | Estimated artefact period: 16.0002
# Sample : 378 | Estimated artefact period: 16.0002
# Sample : 379 | Estimated artefact period: 16.0001
# Sample : 380 | Estimated artefact period: 16.0002
# Sample : 381 | Estimated artefact period: 16.0001
# Sample : 382 | Estimated artefact period: 16.0002
# Sample : 383 | Estimated artefact period: 16.0002
# Sample : 384 | Estimated artefact period: 16.0002
# Sample : 385 | Estimated artefact period: 16.0002
# Sample : 386 | Estimated artefact period: 16.0001
# Sample : 387 | Estimated artefact period: 16.0001
# Sample : 388 | Estimated artefact period: 16.0001
# Sample : 389 | Estimated artefact period: 16.0001
# Sample : 390 | Estimated artefact period: 16.0002
# Sample : 391 | Estimated artefact period: 16.0002
# Sample : 392 | Estimated artefact period: 16.0001
# Sample : 393 | Estimated artefact period: 16.0001
# Sample : 394 | Estimated artefact period: 16.0002
# Sample : 395 | Estimated artefact period: 16.0002
# Sample : 396 | Estimated artefact period: 16.0002
# Sample : 397 | Estimated artefact period: 16.0002
# Sample : 398 | Estimated artefact period: 16.0001
# Sample : 399 | Estimated artefact period: 16.0002
# Sample : 400 | Estimated artefact period: 16.0001
# Sample : 401 | Estimated artefact period: 16.0002
# Sample : 402 | Estimated artefact period: 16.0002
# Sample : 403 | Estimated artefact period: 16.0002
# Sample : 404 | Estimated artefact period: 16.0002
# Sample : 405 | Estimated artefact period: 16.0001
# Sample : 406 | Estimated artefact period: 16.0001
# Sample : 407 | Estimated artefact period: 16.0001
# Sample : 408 | Estimated artefact period: 16.0001
# Sample : 409 | Estimated artefact period: 16.0002
# Sample : 410 | Estimated artefact period: 16.0002
# Sample : 411 | Estimated artefact period: 16.0001
# Sample : 412 | Estimated artefact period: 16.0001
# Sample : 413 | Estimated artefact period: 16.0001
# Sample : 414 | Estimated artefact period: 16.0001
# Sample : 415 | Estimated artefact period: 16.0002
# Sample : 416 | Estimated artefact period: 16.0002
# Sample : 417 | Estimated artefact period: 16.0002
# Sample : 418 | Estimated artefact period: 16.0001
# Sample : 419 | Estimated artefact period: 16.0001
# Sample : 420 | Estimated artefact period: 16.0001
# Sample : 421 | Estimated artefact period: 16.0002
# Sample : 422 | Estimated artefact period: 16.0002
# Sample : 423 | Estimated artefact period: 16.0001
# Sample : 424 | Estimated artefact period: 16.0002
# Sample : 425 | Estimated artefact period: 16.0002
# Sample : 426 | Estimated artefact period: 16.0002
# Sample : 427 | Estimated artefact period: 16.0001
# Sample : 428 | Estimated artefact period: 16.0001
# Sample : 429 | Estimated artefact period: 16.0001
# Sample : 430 | Estimated artefact period: 16.0002
# Sample : 431 | Estimated artefact period: 16.0001
# Sample : 432 | Estimated artefact period: 16.0001
# Sample : 433 | Estimated artefact period: 16.0001
# Sample : 434 | Estimated artefact period: 16.0002
# Sample : 435 | Estimated artefact period: 16.0001
# Sample : 436 | Estimated artefact period: 16.0002
# Sample : 437 | Estimated artefact period: 16.0002
# Sample : 438 | Estimated artefact period: 16.0002
# Sample : 439 | Estimated artefact period: 16.0001
# Sample : 440 | Estimated artefact period: 16.0002
# Sample : 441 | Estimated artefact period: 16.0002
# Sample : 442 | Estimated artefact period: 16.0002
# Sample : 443 | Estimated artefact period: 16.0001
# Sample : 444 | Estimated artefact period: 16.0002
# Sample : 445 | Estimated artefact period: 16.0001
# Sample : 446 | Estimated artefact period: 16.0002
# Sample : 447 | Estimated artefact period: 16.0001
# Sample : 448 | Estimated artefact period: 16.0002
# Sample : 449 | Estimated artefact period: 16.0001
# Sample : 450 | Estimated artefact period: 16.0001
# Sample : 451 | Estimated artefact period: 16.0002
# Sample : 452 | Estimated artefact period: 16.0001
# Sample : 453 | Estimated artefact period: 16.0002
# Sample : 454 | Estimated artefact period: 16.0001
# Sample : 455 | Estimated artefact period: 16.0002
# Sample : 456 | Estimated artefact period: 16.0001
# Sample : 457 | Estimated artefact period: 16.0001
# Sample : 458 | Estimated artefact period: 16.0001
# Sample : 459 | Estimated artefact period: 16.0002
# Sample : 460 | Estimated artefact period: 16.0001
# Sample : 461 | Estimated artefact period: 16.0002
# Sample : 462 | Estimated artefact period: 16.0001
# Sample : 463 | Estimated artefact period: 16.0002
# Sample : 464 | Estimated artefact period: 16.0001
# Sample : 465 | Estimated artefact period: 16.0002
# Sample : 466 | Estimated artefact period: 16.0001
# Sample : 467 | Estimated artefact period: 16.0001
# Sample : 468 | Estimated artefact period: 16.0001
# Sample : 469 | Estimated artefact period: 16.0001
# Sample : 470 | Estimated artefact period: 16.0001
# Sample : 471 | Estimated artefact period: 16.0001
# Sample : 472 | Estimated artefact period: 16.0002
# Sample : 473 | Estimated artefact period: 16.0001
# Sample : 474 | Estimated artefact period: 16.0001
# Sample : 475 | Estimated artefact period: 16.0001
# Sample : 476 | Estimated artefact period: 16.0002
# Sample : 477 | Estimated artefact period: 16.0002
# Sample : 478 | Estimated artefact period: 16.0002
# Sample : 479 | Estimated artefact period: 16.0001
# Sample : 480 | Estimated artefact period: 16.0002
# Sample : 481 | Estimated artefact period: 16.0002
# Sample : 482 | Estimated artefact period: 16.0001
# Sample : 483 | Estimated artefact period: 16.0001
# Sample : 484 | Estimated artefact period: 16.0001
# Sample : 485 | Estimated artefact period: 16.0001
# Sample : 486 | Estimated artefact period: 16.0001
# Sample : 487 | Estimated artefact period: 16.0001
# Sample : 488 | Estimated artefact period: 16.0002
# Sample : 489 | Estimated artefact period: 16.0001
# Sample : 490 | Estimated artefact period: 16.0002
# Sample : 491 | Estimated artefact period: 16.0001
# Sample : 492 | Estimated artefact period: 16.0001
# Sample : 493 | Estimated artefact period: 16.0002
# Sample : 494 | Estimated artefact period: 16.0001
# Sample : 495 | Estimated artefact period: 16.0002
# Sample : 496 | Estimated artefact period: 16.0001
# Sample : 497 | Estimated artefact period: 16.0001
# Sample : 498 | Estimated artefact period: 16.0001
# Sample : 499 | Estimated artefact period: 16.0002
# Sample : 500 | Estimated artefact period: 16.0001
# Sample : 501 | Estimated artefact period: 16.0002
# Sample : 502 | Estimated artefact period: 16.0001
# Sample : 503 | Estimated artefact period: 16.0002
# Sample : 504 | Estimated artefact period: 16.0002
# Sample : 505 | Estimated artefact period: 16.0001
# Sample : 506 | Estimated artefact period: 16.0002
# Sample : 507 | Estimated artefact period: 16.0002
# Sample : 508 | Estimated artefact period: 16.0002
# Sample : 509 | Estimated artefact period: 16.0001
# Sample : 510 | Estimated artefact period: 16.0001
# Sample : 511 | Estimated artefact period: 16.0001
# Sample : 512 | Estimated artefact period: 16.0002
# Sample : 513 | Estimated artefact period: 16.0001
# Sample : 514 | Estimated artefact period: 16.0002
# Sample : 515 | Estimated artefact period: 16.0002
# Sample : 516 | Estimated artefact period: 16.0002
# Sample : 517 | Estimated artefact period: 16.0001
# Sample : 518 | Estimated artefact period: 16.0001
# Sample : 519 | Estimated artefact period: 16.0002
# Sample : 520 | Estimated artefact period: 16.0002
# Sample : 521 | Estimated artefact period: 16.0002
# Sample : 522 | Estimated artefact period: 16.0001
# Sample : 523 | Estimated artefact period: 16.0002
# Sample : 524 | Estimated artefact period: 16.0001
# Sample : 525 | Estimated artefact period: 16.0001
# Sample : 526 | Estimated artefact period: 16.0002
# Sample : 527 | Estimated artefact period: 16.0001
# Sample : 528 | Estimated artefact period: 16.0001
# Sample : 529 | Estimated artefact period: 16.0001
# Sample : 530 | Estimated artefact period: 16.0001
# Sample : 531 | Estimated artefact period: 16.0002
# Sample : 532 | Estimated artefact period: 16.0001
# Sample : 533 | Estimated artefact period: 16.0002
# Sample : 534 | Estimated artefact period: 16.0001
# Sample : 535 | Estimated artefact period: 16.0002
# Sample : 536 | Estimated artefact period: 16.0002
# Sample : 537 | Estimated artefact period: 16.0001
# Sample : 538 | Estimated artefact period: 16.0001
# Sample : 539 | Estimated artefact period: 16.0001
# Sample : 540 | Estimated artefact period: 16.0001
# Sample : 541 | Estimated artefact period: 16.0002
# Sample : 542 | Estimated artefact period: 16.0002
# Sample : 543 | Estimated artefact period: 16.0001
# Sample : 544 | Estimated artefact period: 16.0001
# Sample : 545 | Estimated artefact period: 16.0001
# Sample : 546 | Estimated artefact period: 16.0001
# Sample : 547 | Estimated artefact period: 16.0001
# Sample : 548 | Estimated artefact period: 16.0002
# Sample : 549 | Estimated artefact period: 16.0002
# Sample : 550 | Estimated artefact period: 16.0001
# Sample : 551 | Estimated artefact period: 16.0001
# Sample : 552 | Estimated artefact period: 16.0002
# Sample : 553 | Estimated artefact period: 16.0001
# Sample : 554 | Estimated artefact period: 16.0002
# Sample : 555 | Estimated artefact period: 16.0001
# Sample : 556 | Estimated artefact period: 16.0002
# Sample : 557 | Estimated artefact period: 16.0002
# Sample : 558 | Estimated artefact period: 16.0001
# Sample : 559 | Estimated artefact period: 16.0002
# Sample : 560 | Estimated artefact period: 16.0002
# Sample : 561 | Estimated artefact period: 16.0001
# Sample : 562 | Estimated artefact period: 16.0001
# Sample : 563 | Estimated artefact period: 16.0002
# Sample : 564 | Estimated artefact period: 16.0002
# Sample : 565 | Estimated artefact period: 16.0001
# Sample : 566 | Estimated artefact period: 16.0001
# Sample : 567 | Estimated artefact period: 16.0001
# Sample : 568 | Estimated artefact period: 16.0002
# Sample : 569 | Estimated artefact period: 16.0002
# Sample : 570 | Estimated artefact period: 16.0001
# Sample : 571 | Estimated artefact period: 16.0001
# Sample : 572 | Estimated artefact period: 16.0001
# Sample : 573 | Estimated artefact period: 16.0001
# Sample : 574 | Estimated artefact period: 16.0001
# Sample : 575 | Estimated artefact period: 16.0002
# Sample : 576 | Estimated artefact period: 16.0001
# Sample : 577 | Estimated artefact period: 16.0001
# Sample : 578 | Estimated artefact period: 16.0001
# Sample : 579 | Estimated artefact period: 16.0001
# Sample : 580 | Estimated artefact period: 16.0001
# Sample : 581 | Estimated artefact period: 16.0002
# Sample : 582 | Estimated artefact period: 16.0001
# Sample : 583 | Estimated artefact period: 16.0002
# Sample : 584 | Estimated artefact period: 16.0001
# Sample : 585 | Estimated artefact period: 16.0001
# Sample : 586 | Estimated artefact period: 16.0001
# Sample : 587 | Estimated artefact period: 16.0002
# Sample : 588 | Estimated artefact period: 16.0002
# Sample : 589 | Estimated artefact period: 16.0002
# Sample : 590 | Estimated artefact period: 16.0002
# Sample : 591 | Estimated artefact period: 16.0001
# Sample : 592 | Estimated artefact period: 16.0001
# Sample : 593 | Estimated artefact period: 16.0001
# Sample : 594 | Estimated artefact period: 16.0001
# Sample : 595 | Estimated artefact period: 16.0002
# Sample : 596 | Estimated artefact period: 16.0002
# Sample : 597 | Estimated artefact period: 16.0002
# Sample : 598 | Estimated artefact period: 16.0002
# Sample : 599 | Estimated artefact period: 16.0001
# Sample : 600 | Estimated artefact period: 16.0002
# Sample : 601 | Estimated artefact period: 16.0001
# Sample : 602 | Estimated artefact period: 16.0001
# Sample : 603 | Estimated artefact period: 16.0001
# Sample : 604 | Estimated artefact period: 16.0002
# Sample : 605 | Estimated artefact period: 16.0001
# Sample : 606 | Estimated artefact period: 16.0002
# Sample : 607 | Estimated artefact period: 16.0001
# Sample : 608 | Estimated artefact period: 16.0002
# Sample : 609 | Estimated artefact period: 16.0001
# Sample : 610 | Estimated artefact period: 16.0001
# Sample : 611 | Estimated artefact period: 16.0001
# Sample : 612 | Estimated artefact period: 16.0001
# Sample : 613 | Estimated artefact period: 16.0002
# Sample : 614 | Estimated artefact period: 16.0001
# Sample : 615 | Estimated artefact period: 16.0001
# Sample : 616 | Estimated artefact period: 16.0001
# Sample : 617 | Estimated artefact period: 16.0001
# Sample : 618 | Estimated artefact period: 16.0002
# Sample : 619 | Estimated artefact period: 16.0002
# Sample : 620 | Estimated artefact period: 16.0001
# Sample : 621 | Estimated artefact period: 16.0001
# Sample : 622 | Estimated artefact period: 16.0002
# Sample : 623 | Estimated artefact period: 16.0002
# Sample : 624 | Estimated artefact period: 16.0001
# Sample : 625 | Estimated artefact period: 16.0001
# Sample : 626 | Estimated artefact period: 16.0002
# Sample : 627 | Estimated artefact period: 16.0001
# Sample : 628 | Estimated artefact period: 16.0001
# Sample : 629 | Estimated artefact period: 16.0002
# Sample : 630 | Estimated artefact period: 16.0001
# Sample : 631 | Estimated artefact period: 16.0001
# Sample : 632 | Estimated artefact period: 16.0002
# Sample : 633 | Estimated artefact period: 16.0002
# Sample : 634 | Estimated artefact period: 16.0002
# Sample : 635 | Estimated artefact period: 16.0002
# Sample : 636 | Estimated artefact period: 16.0002
# Sample : 637 | Estimated artefact period: 16.0001
# Sample : 638 | Estimated artefact period: 16.0001
# Sample : 639 | Estimated artefact period: 16.0001
# Sample : 640 | Estimated artefact period: 16.0002
# Sample : 641 | Estimated artefact period: 16.0002
# Sample : 642 | Estimated artefact period: 16.0001
# Sample : 643 | Estimated artefact period: 16.0001
# Sample : 644 | Estimated artefact period: 16.0002
# Sample : 645 | Estimated artefact period: 16.0001
# Sample : 646 | Estimated artefact period: 16.0002
# Sample : 647 | Estimated artefact period: 16.0001
# Sample : 648 | Estimated artefact period: 16.0001
# Sample : 649 | Estimated artefact period: 16.0002
# Sample : 650 | Estimated artefact period: 16.0002
# Sample : 651 | Estimated artefact period: 16.0002
# Sample : 652 | Estimated artefact period: 16.0001
# Sample : 653 | Estimated artefact period: 16.0001
# Sample : 654 | Estimated artefact period: 16.0001
# Sample : 655 | Estimated artefact period: 16.0002
# Sample : 656 | Estimated artefact period: 16.0001
# Sample : 657 | Estimated artefact period: 16.0000
# Sample : 658 | Estimated artefact period: 16.0001
# Sample : 659 | Estimated artefact period: 16.0001
# Sample : 660 | Estimated artefact period: 16.0002
# Sample : 661 | Estimated artefact period: 16.0002
# Sample : 662 | Estimated artefact period: 16.0002
# Sample : 663 | Estimated artefact period: 16.0001
# Sample : 664 | Estimated artefact period: 16.0002
# Sample : 665 | Estimated artefact period: 16.0001
# Sample : 666 | Estimated artefact period: 16.0002
# Sample : 667 | Estimated artefact period: 16.0002
# Sample : 668 | Estimated artefact period: 16.0001
# Sample : 669 | Estimated artefact period: 16.0002
# Sample : 670 | Estimated artefact period: 16.0002
# Sample : 671 | Estimated artefact period: 16.0001
# Sample : 672 | Estimated artefact period: 16.0001
# Sample : 673 | Estimated artefact period: 16.0002
# Sample : 674 | Estimated artefact period: 16.0002
# Sample : 675 | Estimated artefact period: 16.0002
# Sample : 676 | Estimated artefact period: 16.0001
# Sample : 677 | Estimated artefact period: 16.0002
# Sample : 678 | Estimated artefact period: 16.0001
# Sample : 679 | Estimated artefact period: 16.0001
# Sample : 680 | Estimated artefact period: 16.0001
# Sample : 681 | Estimated artefact period: 16.0002
# Sample : 682 | Estimated artefact period: 16.0001
# Sample : 683 | Estimated artefact period: 16.0002
# Sample : 684 | Estimated artefact period: 16.0002
# Sample : 685 | Estimated artefact period: 16.0001
# Sample : 686 | Estimated artefact period: 16.0002
# Sample : 687 | Estimated artefact period: 16.0002
# Sample : 688 | Estimated artefact period: 16.0001
# Sample : 689 | Estimated artefact period: 16.0001
# Sample : 690 | Estimated artefact period: 16.0002
# Sample : 691 | Estimated artefact period: 16.0001
# Sample : 692 | Estimated artefact period: 16.0001
# Sample : 693 | Estimated artefact period: 16.0001
# Sample : 694 | Estimated artefact period: 16.0002
# Sample : 695 | Estimated artefact period: 16.0002
# Sample : 696 | Estimated artefact period: 16.0002
# Sample : 697 | Estimated artefact period: 16.0002
# Sample : 698 | Estimated artefact period: 16.0002
# Sample : 699 | Estimated artefact period: 16.0001
# Sample : 700 | Estimated artefact period: 16.0001
# Sample : 701 | Estimated artefact period: 16.0002
# Sample : 702 | Estimated artefact period: 16.0002
# Sample : 703 | Estimated artefact period: 16.0002
# Sample : 704 | Estimated artefact period: 16.0002
# Sample : 705 | Estimated artefact period: 16.0002
# Sample : 706 | Estimated artefact period: 16.0001
# Sample : 707 | Estimated artefact period: 16.0001
# Sample : 708 | Estimated artefact period: 16.0002
# Sample : 709 | Estimated artefact period: 16.0002
# Sample : 710 | Estimated artefact period: 16.0002
# Sample : 711 | Estimated artefact period: 16.0001
# Sample : 712 | Estimated artefact period: 16.0001
# Sample : 713 | Estimated artefact period: 16.0001
# Sample : 714 | Estimated artefact period: 16.0002
# Sample : 715 | Estimated artefact period: 16.0002
# Sample : 716 | Estimated artefact period: 16.0002
# Sample : 717 | Estimated artefact period: 16.0002
# Sample : 718 | Estimated artefact period: 16.0001
# Sample : 719 | Estimated artefact period: 16.0001
# Sample : 720 | Estimated artefact period: 16.0001
# Sample : 721 | Estimated artefact period: 16.0001
# Sample : 722 | Estimated artefact period: 16.0002
# Sample : 723 | Estimated artefact period: 16.0002
# Sample : 724 | Estimated artefact period: 16.0001
# Sample : 725 | Estimated artefact period: 16.0001
# Sample : 726 | Estimated artefact period: 16.0002
# Sample : 727 | Estimated artefact period: 16.0002
# Sample : 728 | Estimated artefact period: 16.0002
# Sample : 729 | Estimated artefact period: 16.0002
# Sample : 730 | Estimated artefact period: 16.0001
# Sample : 731 | Estimated artefact period: 16.0001
# Sample : 732 | Estimated artefact period: 16.0002
# Sample : 733 | Estimated artefact period: 16.0001
# Sample : 734 | Estimated artefact period: 16.0002
# Sample : 735 | Estimated artefact period: 16.0002
# Sample : 736 | Estimated artefact period: 16.0001
# Sample : 737 | Estimated artefact period: 16.0001
# Sample : 738 | Estimated artefact period: 16.0001
# Sample : 739 | Estimated artefact period: 16.0002
# Sample : 740 | Estimated artefact period: 16.0002
# Sample : 741 | Estimated artefact period: 16.0002
# Sample : 742 | Estimated artefact period: 16.0002
# Sample : 743 | Estimated artefact period: 16.0001
# Sample : 744 | Estimated artefact period: 16.0001
# Sample : 745 | Estimated artefact period: 16.0002
# Sample : 746 | Estimated artefact period: 16.0001
# Sample : 747 | Estimated artefact period: 16.0001
# Sample : 748 | Estimated artefact period: 16.0002
# Sample : 749 | Estimated artefact period: 16.0001
# Sample : 750 | Estimated artefact period: 16.0001
# Sample : 751 | Estimated artefact period: 16.0002
# Sample : 752 | Estimated artefact period: 16.0002
# Sample : 753 | Estimated artefact period: 16.0001
# Sample : 754 | Estimated artefact period: 16.0001
# Sample : 755 | Estimated artefact period: 16.0001
# Sample : 756 | Estimated artefact period: 16.0002
# Sample : 757 | Estimated artefact period: 16.0002
# Sample : 758 | Estimated artefact period: 16.0002
# Sample : 759 | Estimated artefact period: 16.0002
# Sample : 760 | Estimated artefact period: 16.0002
# Sample : 761 | Estimated artefact period: 16.0002
# Sample : 762 | Estimated artefact period: 16.0001
# Sample : 763 | Estimated artefact period: 16.0002
# Sample : 764 | Estimated artefact period: 16.0002
# Sample : 765 | Estimated artefact period: 16.0002
# Sample : 766 | Estimated artefact period: 16.0002
# Sample : 767 | Estimated artefact period: 16.0002
# Sample : 768 | Estimated artefact period: 16.0002
# Sample : 769 | Estimated artefact period: 16.0002
# Sample : 770 | Estimated artefact period: 16.0001
# Sample : 771 | Estimated artefact period: 16.0001
# Sample : 772 | Estimated artefact period: 16.0002
# Sample : 773 | Estimated artefact period: 16.0001
# Sample : 774 | Estimated artefact period: 16.0001
# Sample : 775 | Estimated artefact period: 16.0002
# Sample : 776 | Estimated artefact period: 16.0001
# Sample : 777 | Estimated artefact period: 16.0001
# Sample : 778 | Estimated artefact period: 16.0002
# Sample : 779 | Estimated artefact period: 16.0002
# Sample : 780 | Estimated artefact period: 16.0001
# Sample : 781 | Estimated artefact period: 16.0001
# Sample : 782 | Estimated artefact period: 16.0001
# Sample : 783 | Estimated artefact period: 16.0001
# Sample : 784 | Estimated artefact period: 16.0002
# Sample : 785 | Estimated artefact period: 16.0002
# Sample : 786 | Estimated artefact period: 16.0002
# Sample : 787 | Estimated artefact period: 16.0001
# Sample : 788 | Estimated artefact period: 16.0002
# Sample : 789 | Estimated artefact period: 16.0002
# Sample : 790 | Estimated artefact period: 16.0001
# Sample : 791 | Estimated artefact period: 16.0001
# Sample : 792 | Estimated artefact period: 16.0000
# Sample : 793 | Estimated artefact period: 16.0002
# Sample : 794 | Estimated artefact period: 16.0001
# Sample : 795 | Estimated artefact period: 16.0001
# Sample : 796 | Estimated artefact period: 16.0001
# Sample : 797 | Estimated artefact period: 16.0002
# Sample : 798 | Estimated artefact period: 16.0001
# Sample : 799 | Estimated artefact period: 16.0002
# Sample : 800 | Estimated artefact period: 16.0001
# Sample : 801 | Estimated artefact period: 16.0001
# Sample : 802 | Estimated artefact period: 16.0002
# Sample : 803 | Estimated artefact period: 16.0002
# Sample : 804 | Estimated artefact period: 16.0002
# Sample : 805 | Estimated artefact period: 16.0002
# Sample : 806 | Estimated artefact period: 16.0002
# Sample : 807 | Estimated artefact period: 16.0002
# Sample : 808 | Estimated artefact period: 16.0002
# Sample : 809 | Estimated artefact period: 16.0001
# Sample : 810 | Estimated artefact period: 16.0002
# Sample : 811 | Estimated artefact period: 16.0001
# Sample : 812 | Estimated artefact period: 16.0001
# Sample : 813 | Estimated artefact period: 16.0002
# Sample : 814 | Estimated artefact period: 16.0001
# Sample : 815 | Estimated artefact period: 16.0002
# Sample : 816 | Estimated artefact period: 16.0001
# Sample : 817 | Estimated artefact period: 16.0001
# Sample : 818 | Estimated artefact period: 16.0001
# Sample : 819 | Estimated artefact period: 16.0002
# Sample : 820 | Estimated artefact period: 16.0001
# Sample : 821 | Estimated artefact period: 16.0001
# Sample : 822 | Estimated artefact period: 16.0001
# Sample : 823 | Estimated artefact period: 16.0001
# Sample : 824 | Estimated artefact period: 16.0002
# Sample : 825 | Estimated artefact period: 16.0001
# Sample : 826 | Estimated artefact period: 16.0001
# Sample : 827 | Estimated artefact period: 16.0002
# Sample : 828 | Estimated artefact period: 16.0002
# Sample : 829 | Estimated artefact period: 16.0001
# Sample : 830 | Estimated artefact period: 16.0001
# Sample : 831 | Estimated artefact period: 16.0001
# Sample : 832 | Estimated artefact period: 16.0002
# Sample : 833 | Estimated artefact period: 16.0001
# Sample : 834 | Estimated artefact period: 16.0001
# Sample : 835 | Estimated artefact period: 16.0001
# Sample : 836 | Estimated artefact period: 16.0002
# Sample : 837 | Estimated artefact period: 16.0001
# Sample : 838 | Estimated artefact period: 16.0001
# Sample : 839 | Estimated artefact period: 16.0001
# Sample : 840 | Estimated artefact period: 16.0002
# Sample : 841 | Estimated artefact period: 16.0002
# Sample : 842 | Estimated artefact period: 16.0002
# Sample : 843 | Estimated artefact period: 16.0002
# Sample : 844 | Estimated artefact period: 16.0002
# Sample : 845 | Estimated artefact period: 16.0002
# Sample : 846 | Estimated artefact period: 16.0002
# Sample : 847 | Estimated artefact period: 16.0002
# Sample : 848 | Estimated artefact period: 16.0001
# Sample : 849 | Estimated artefact period: 16.0001
# Sample : 850 | Estimated artefact period: 16.0001
# Sample : 851 | Estimated artefact period: 16.0002
# Sample : 852 | Estimated artefact period: 16.0001
# Sample : 853 | Estimated artefact period: 16.0001
# Sample : 854 | Estimated artefact period: 16.0001
# Sample : 855 | Estimated artefact period: 16.0001
# Sample : 856 | Estimated artefact period: 16.0001
# Sample : 857 | Estimated artefact period: 16.0002
# Sample : 858 | Estimated artefact period: 16.0002
# Sample : 859 | Estimated artefact period: 16.0002
# Sample : 860 | Estimated artefact period: 16.0002
# Sample : 861 | Estimated artefact period: 16.0002
# Sample : 862 | Estimated artefact period: 16.0001
# Sample : 863 | Estimated artefact period: 16.0002
# Sample : 864 | Estimated artefact period: 16.0002
# Sample : 865 | Estimated artefact period: 16.0002
# Sample : 866 | Estimated artefact period: 16.0001
# Sample : 867 | Estimated artefact period: 16.0001
# Sample : 868 | Estimated artefact period: 16.0001
# Sample : 869 | Estimated artefact period: 16.0002
# Sample : 870 | Estimated artefact period: 16.0002
# Sample : 871 | Estimated artefact period: 16.0001
# Sample : 872 | Estimated artefact period: 16.0002
# Sample : 873 | Estimated artefact period: 16.0001
# Sample : 874 | Estimated artefact period: 16.0001
# Sample : 875 | Estimated artefact period: 16.0002
# Sample : 876 | Estimated artefact period: 16.0001
# Sample : 877 | Estimated artefact period: 16.0001
# Sample : 878 | Estimated artefact period: 16.0002
# Sample : 879 | Estimated artefact period: 16.0001
# Sample : 880 | Estimated artefact period: 16.0002
# Sample : 881 | Estimated artefact period: 16.0001
# Sample : 882 | Estimated artefact period: 16.0001
# Sample : 883 | Estimated artefact period: 16.0002
# Sample : 884 | Estimated artefact period: 16.0001
# Sample : 885 | Estimated artefact period: 16.0001
# Sample : 886 | Estimated artefact period: 16.0002
# Sample : 887 | Estimated artefact period: 16.0002
# Sample : 888 | Estimated artefact period: 16.0001
# Sample : 889 | Estimated artefact period: 16.0001
# Sample : 890 | Estimated artefact period: 16.0002
# Sample : 891 | Estimated artefact period: 16.0001
# Sample : 892 | Estimated artefact period: 16.0001
# Sample : 893 | Estimated artefact period: 16.0001
# Sample : 894 | Estimated artefact period: 16.0002
# Sample : 895 | Estimated artefact period: 16.0002
# Sample : 896 | Estimated artefact period: 16.0002
# Sample : 897 | Estimated artefact period: 16.0001
# Sample : 898 | Estimated artefact period: 16.0001
# Sample : 899 | Estimated artefact period: 16.0002
# Sample : 900 | Estimated artefact period: 16.0002
# Sample : 901 | Estimated artefact period: 16.0001
# Sample : 902 | Estimated artefact period: 16.0002
# Sample : 903 | Estimated artefact period: 16.0001
# Sample : 904 | Estimated artefact period: 16.0001
# Sample : 905 | Estimated artefact period: 16.0002
# Sample : 906 | Estimated artefact period: 16.0002
# Sample : 907 | Estimated artefact period: 16.0001
# Sample : 908 | Estimated artefact period: 16.0001
# Sample : 909 | Estimated artefact period: 16.0001
# Sample : 910 | Estimated artefact period: 16.0001
# Sample : 911 | Estimated artefact period: 16.0002
# Sample : 912 | Estimated artefact period: 16.0002
# Sample : 913 | Estimated artefact period: 16.0001
# Sample : 914 | Estimated artefact period: 16.0002
# Sample : 915 | Estimated artefact period: 16.0001
# Sample : 916 | Estimated artefact period: 16.0002
# Sample : 917 | Estimated artefact period: 16.0002
# Sample : 918 | Estimated artefact period: 16.0001
# Sample : 919 | Estimated artefact period: 16.0001
# Sample : 920 | Estimated artefact period: 16.0002
# Sample : 921 | Estimated artefact period: 16.0001
# Sample : 922 | Estimated artefact period: 16.0002
# Sample : 923 | Estimated artefact period: 16.0001
# Sample : 924 | Estimated artefact period: 16.0001
# Sample : 925 | Estimated artefact period: 16.0002
# Sample : 926 | Estimated artefact period: 16.0001
# Sample : 927 | Estimated artefact period: 16.0002
# Sample : 928 | Estimated artefact period: 16.0002
# Sample : 929 | Estimated artefact period: 16.0001
# Sample : 930 | Estimated artefact period: 16.0002
# Sample : 931 | Estimated artefact period: 16.0001
# Sample : 932 | Estimated artefact period: 16.0001
# Sample : 933 | Estimated artefact period: 16.0002
# Sample : 934 | Estimated artefact period: 16.0002
# Sample : 935 | Estimated artefact period: 16.0001
# Sample : 936 | Estimated artefact period: 16.0002
# Sample : 937 | Estimated artefact period: 16.0001
# Sample : 938 | Estimated artefact period: 16.0002
# Sample : 939 | Estimated artefact period: 16.0002
# Sample : 940 | Estimated artefact period: 16.0002
# Sample : 941 | Estimated artefact period: 16.0002
# Sample : 942 | Estimated artefact period: 16.0001
# Sample : 943 | Estimated artefact period: 16.0002
# Sample : 944 | Estimated artefact period: 16.0002
# Sample : 945 | Estimated artefact period: 16.0002
# Sample : 946 | Estimated artefact period: 16.0002
# Sample : 947 | Estimated artefact period: 16.0002
# Sample : 948 | Estimated artefact period: 16.0001
# Sample : 949 | Estimated artefact period: 16.0001
# Sample : 950 | Estimated artefact period: 16.0001
# Sample : 951 | Estimated artefact period: 16.0001
# Sample : 952 | Estimated artefact period: 16.0001
# Sample : 953 | Estimated artefact period: 16.0001
# Sample : 954 | Estimated artefact period: 16.0002
# Sample : 955 | Estimated artefact period: 16.0002
# Sample : 956 | Estimated artefact period: 16.0002
# Sample : 957 | Estimated artefact period: 16.0002
# Sample : 958 | Estimated artefact period: 16.0002
# Sample : 959 | Estimated artefact period: 16.0002
# Sample : 960 | Estimated artefact period: 16.0001
# Sample : 961 | Estimated artefact period: 16.0002
# ...
# Sample : 1687 | Estimated artefact period: 16.0002
# Sample : 1688 | Estimated artefact period: 16.0001
# Sample : 1689 | Estimated artefact period: 16.0001
# Sample : 1690 | Estimated artefact period: 16.0001
# Sample : 1691 | Estimated artefact period: 16.0001
# Sample : 1692 | Estimated artefact period: 16.0002
# Sample : 1693 | Estimated artefact period: 16.0002
# Sample : 1694 | Estimated artefact period: 16.0001
# Sample : 1695 | Estimated artefact period: 16.0002
# Sample : 1696 | Estimated artefact period: 16.0001
# Sample : 1697 | Estimated artefact period: 16.0002
# Sample : 1698 | Estimated artefact period: 16.0001
# Sample : 1699 | Estimated artefact period: 16.0002
# Sample : 1700 | Estimated artefact period: 16.0001
# Sample : 1701 | Estimated artefact period: 16.0001
# Sample : 1702 | Estimated artefact period: 16.0002
# Sample : 1703 | Estimated artefact period: 16.0002
# Sample : 1704 | Estimated artefact period: 16.0002
# Sample : 1705 | Estimated artefact period: 16.0002
# Sample : 1706 | Estimated artefact period: 16.0001
# Sample : 1707 | Estimated artefact period: 16.0002
# Sample : 1708 | Estimated artefact period: 16.0001
# Sample : 1709 | Estimated artefact period: 16.0001
# Sample : 1710 | Estimated artefact period: 16.0002
# Sample : 1711 | Estimated artefact period: 16.0002
# Sample : 1712 | Estimated artefact period: 16.0002
# Sample : 1713 | Estimated artefact period: 16.0002
# Sample : 1714 | Estimated artefact period: 16.0002
# Sample : 1715 | Estimated artefact period: 16.0001
# Sample : 1716 | Estimated artefact period: 16.0002
# Sample : 1717 | Estimated artefact period: 16.0002
# Sample : 1718 | Estimated artefact period: 16.0001
# Sample : 1719 | Estimated artefact period: 16.0001
# Sample : 1720 | Estimated artefact period: 16.0001
# Sample : 1721 | Estimated artefact period: 16.0002
# Sample : 1722 | Estimated artefact period: 16.0001
# Sample : 1723 | Estimated artefact period: 16.0002
# Sample : 1724 | Estimated artefact period: 16.0001
# Sample : 1725 | Estimated artefact period: 16.0001
# Sample : 1726 | Estimated artefact period: 16.0002
# Sample : 1727 | Estimated artefact period: 16.0001
# Sample : 1728 | Estimated artefact period: 16.0001
# Sample : 1729 | Estimated artefact period: 16.0002
# Sample : 1730 | Estimated artefact period: 16.0001
# Sample : 1731 | Estimated artefact period: 16.0002
# Sample : 1732 | Estimated artefact period: 16.0002
# Sample : 1733 | Estimated artefact period: 16.0001
# Sample : 1734 | Estimated artefact period: 16.0002
# Sample : 1735 | Estimated artefact period: 16.0001
# Sample : 1736 | Estimated artefact period: 16.0002
# Sample : 1737 | Estimated artefact period: 16.0001
# Sample : 1738 | Estimated artefact period: 16.0002
# Sample : 1739 | Estimated artefact period: 16.0002
# Sample : 1740 | Estimated artefact period: 16.0001
# Sample : 1741 | Estimated artefact period: 16.0001
# Sample : 1742 | Estimated artefact period: 16.0002
# Sample : 1743 | Estimated artefact period: 16.0002
# Sample : 1744 | Estimated artefact period: 16.0001
# Sample : 1745 | Estimated artefact period: 16.0001
# Sample : 1746 | Estimated artefact period: 16.0001
# Sample : 1747 | Estimated artefact period: 16.0001
# Sample : 1748 | Estimated artefact period: 16.0002
# Sample : 1749 | Estimated artefact period: 16.0002
# Sample : 1750 | Estimated artefact period: 16.0001
# Sample : 1751 | Estimated artefact period: 16.0001
# Sample : 1752 | Estimated artefact period: 16.0002
# Sample : 1753 | Estimated artefact period: 16.0002
# Sample : 1754 | Estimated artefact period: 16.0001
# Sample : 1755 | Estimated artefact period: 16.0002
# Sample : 1756 | Estimated artefact period: 16.0002
# Sample : 1757 | Estimated artefact period: 16.0001
# Sample : 1758 | Estimated artefact period: 16.0001
# Sample : 1759 | Estimated artefact period: 16.0002
# Sample : 1760 | Estimated artefact period: 16.0002
# Sample : 1761 | Estimated artefact period: 16.0002
# Sample : 1762 | Estimated artefact period: 16.0001
# Sample : 1763 | Estimated artefact period: 16.0002
# Sample : 1764 | Estimated artefact period: 16.0001
# Sample : 1765 | Estimated artefact period: 16.0001
# Sample : 1766 | Estimated artefact period: 16.0001
# Sample : 1767 | Estimated artefact period: 16.0001
# Sample : 1768 | Estimated artefact period: 16.0002
# Sample : 1769 | Estimated artefact period: 16.0001
# Sample : 1770 | Estimated artefact period: 16.0002
# Sample : 1771 | Estimated artefact period: 16.0002
# Sample : 1772 | Estimated artefact period: 16.0002
# Sample : 1773 | Estimated artefact period: 16.0001
# Sample : 1774 | Estimated artefact period: 16.0002
# Sample : 1775 | Estimated artefact period: 16.0001
# Sample : 1776 | Estimated artefact period: 16.0002
# Sample : 1777 | Estimated artefact period: 16.0001
# Sample : 1778 | Estimated artefact period: 16.0001
# Sample : 1779 | Estimated artefact period: 16.0001
# Sample : 1780 | Estimated artefact period: 16.0002
# Sample : 1781 | Estimated artefact period: 16.0002
# Sample : 1782 | Estimated artefact period: 16.0002
# Sample : 1783 | Estimated artefact period: 16.0002
# Sample : 1784 | Estimated artefact period: 16.0002
# Sample : 1785 | Estimated artefact period: 16.0001
# Sample : 1786 | Estimated artefact period: 16.0002
# Sample : 1787 | Estimated artefact period: 16.0002
# Sample : 1788 | Estimated artefact period: 16.0002
# Sample : 1789 | Estimated artefact period: 16.0002
# Sample : 1790 | Estimated artefact period: 16.0002
# Sample : 1791 | Estimated artefact period: 16.0001
# Sample : 1792 | Estimated artefact period: 16.0002
# Sample : 1793 | Estimated artefact period: 16.0001
# Sample : 1794 | Estimated artefact period: 16.0001
# Sample : 1795 | Estimated artefact period: 16.0001
# Sample : 1796 | Estimated artefact period: 16.0002
# Sample : 1797 | Estimated artefact period: 16.0002
# Sample : 1798 | Estimated artefact period: 16.0002
# Sample : 1799 | Estimated artefact period: 16.0002
# Sample : 1800 | Estimated artefact period: 16.0002
# Sample : 1801 | Estimated artefact period: 16.0002
# Sample : 1802 | Estimated artefact period: 16.0002
# Sample : 1803 | Estimated artefact period: 16.0002
# Sample : 1804 | Estimated artefact period: 16.0002
# Sample : 1805 | Estimated artefact period: 16.0001
# Sample : 1806 | Estimated artefact period: 16.0002
# Sample : 1807 | Estimated artefact period: 16.0001
# Sample : 1808 | Estimated artefact period: 16.0001
# Sample : 1809 | Estimated artefact period: 16.0001
# Sample : 1810 | Estimated artefact period: 16.0002
# Sample : 1811 | Estimated artefact period: 16.0001
# Sample : 1812 | Estimated artefact period: 16.0001
# Sample : 1813 | Estimated artefact period: 16.0002
# Sample : 1814 | Estimated artefact period: 16.0001
# Sample : 1815 | Estimated artefact period: 16.0002
# Sample : 1816 | Estimated artefact period: 16.0001
# Sample : 1817 | Estimated artefact period: 16.0001
# Sample : 1818 | Estimated artefact period: 16.0001
# Sample : 1819 | Estimated artefact period: 16.0002
# Sample : 1820 | Estimated artefact period: 16.0002
# Sample : 1821 | Estimated artefact period: 16.0001
# Sample : 1822 | Estimated artefact period: 16.0002
# Sample : 1823 | Estimated artefact period: 16.0002
# Sample : 1824 | Estimated artefact period: 16.0002
# Sample : 1825 | Estimated artefact period: 16.0002
# Sample : 1826 | Estimated artefact period: 16.0002
# Sample : 1827 | Estimated artefact period: 16.0002
# Sample : 1828 | Estimated artefact period: 16.0001
# Sample : 1829 | Estimated artefact period: 16.0002
# Sample : 1830 | Estimated artefact period: 16.0002
# Sample : 1831 | Estimated artefact period: 16.0001
# Sample : 1832 | Estimated artefact period: 16.0002
# Sample : 1833 | Estimated artefact period: 16.0002
# Sample : 1834 | Estimated artefact period: 16.0002
# Sample : 1835 | Estimated artefact period: 16.0002
# Sample : 1836 | Estimated artefact period: 16.0002
# Sample : 1837 | Estimated artefact period: 16.0001
# Sample : 1838 | Estimated artefact period: 16.0001
# Sample : 1839 | Estimated artefact period: 16.0001
# Sample : 1840 | Estimated artefact period: 16.0001
# Sample : 1841 | Estimated artefact period: 16.0001
# Sample : 1842 | Estimated artefact period: 16.0002
# Sample : 1843 | Estimated artefact period: 16.0002
# Sample : 1844 | Estimated artefact period: 16.0001
# Sample : 1845 | Estimated artefact period: 16.0002
# Sample : 1846 | Estimated artefact period: 16.0001
# Sample : 1847 | Estimated artefact period: 16.0001
# Sample : 1848 | Estimated artefact period: 16.0001
# Sample : 1849 | Estimated artefact period: 16.0002
# Sample : 1850 | Estimated artefact period: 16.0001
# Sample : 1851 | Estimated artefact period: 16.0001
# Sample : 1852 | Estimated artefact period: 16.0001
# Sample : 1853 | Estimated artefact period: 16.0002
# Sample : 1854 | Estimated artefact period: 16.0002
# Sample : 1855 | Estimated artefact period: 16.0002
# Sample : 1856 | Estimated artefact period: 16.0002
# Sample : 1857 | Estimated artefact period: 16.0002
# Sample : 1858 | Estimated artefact period: 16.0002
# Sample : 1859 | Estimated artefact period: 16.0001
# Sample : 1860 | Estimated artefact period: 16.0001
# Sample : 1861 | Estimated artefact period: 16.0002
# Sample : 1862 | Estimated artefact period: 16.0001
# Sample : 1863 | Estimated artefact period: 16.0001
# Sample : 1864 | Estimated artefact period: 16.0001
# Sample : 1865 | Estimated artefact period: 16.0001
# Sample : 1866 | Estimated artefact period: 16.0001
# Sample : 1867 | Estimated artefact period: 16.0002
# Sample : 1868 | Estimated artefact period: 16.0002
# Sample : 1869 | Estimated artefact period: 16.0002
# Sample : 1870 | Estimated artefact period: 16.0002
# Sample : 1871 | Estimated artefact period: 16.0001
# Sample : 1872 | Estimated artefact period: 16.0002
# Sample : 1873 | Estimated artefact period: 16.0001
# Sample : 1874 | Estimated artefact period: 16.0001
# Sample : 1875 | Estimated artefact period: 16.0002
# Sample : 1876 | Estimated artefact period: 16.0002
# Sample : 1877 | Estimated artefact period: 16.0001
# Sample : 1878 | Estimated artefact period: 16.0002
# Sample : 1879 | Estimated artefact period: 16.0002
# Sample : 1880 | Estimated artefact period: 16.0002
# Sample : 1881 | Estimated artefact period: 16.0001
# Sample : 1882 | Estimated artefact period: 16.0001
# Sample : 1883 | Estimated artefact period: 16.0002
# Sample : 1884 | Estimated artefact period: 16.0001
# Sample : 1885 | Estimated artefact period: 16.0002
# Sample : 1886 | Estimated artefact period: 16.0001
# Sample : 1887 | Estimated artefact period: 16.0001
# Sample : 1888 | Estimated artefact period: 16.0001
# Sample : 1889 | Estimated artefact period: 16.0002
# Sample : 1890 | Estimated artefact period: 16.0001
# Sample : 1891 | Estimated artefact period: 16.0001
# Sample : 1892 | Estimated artefact period: 16.0001
# Sample : 1893 | Estimated artefact period: 16.0002
# Sample : 1894 | Estimated artefact period: 16.0001
# Sample : 1895 | Estimated artefact period: 16.0002
# Sample : 1896 | Estimated artefact period: 16.0001
# Sample : 1897 | Estimated artefact period: 16.0002
# Sample : 1898 | Estimated artefact period: 16.0001
# Sample : 1899 | Estimated artefact period: 16.0001
# Sample : 1900 | Estimated artefact period: 16.0001
# Sample : 1901 | Estimated artefact period: 16.0002
# Sample : 1902 | Estimated artefact period: 16.0001
# Sample : 1903 | Estimated artefact period: 16.0002
# Sample : 1904 | Estimated artefact period: 16.0001
# Sample : 1905 | Estimated artefact period: 16.0001
# Sample : 1906 | Estimated artefact period: 16.0002
# Sample : 1907 | Estimated artefact period: 16.0002
# Sample : 1908 | Estimated artefact period: 16.0002
# Sample : 1909 | Estimated artefact period: 16.0002
# Sample : 1910 | Estimated artefact period: 16.0001
# Sample : 1911 | Estimated artefact period: 16.0001
# Sample : 1912 | Estimated artefact period: 16.0002
# Sample : 1913 | Estimated artefact period: 16.0002
# Sample : 1914 | Estimated artefact period: 16.0001
# Sample : 1915 | Estimated artefact period: 16.0002
# Sample : 1916 | Estimated artefact period: 16.0001
# Sample : 1917 | Estimated artefact period: 16.0002
# Sample : 1918 | Estimated artefact period: 16.0001
# Sample : 1919 | Estimated artefact period: 16.0001
# Sample : 1920 | Estimated artefact period: 16.0002
# Sample : 1921 | Estimated artefact period: 16.0001
# Sample : 1922 | Estimated artefact period: 16.0002
# Sample : 1923 | Estimated artefact period: 16.0002
# Sample : 1924 | Estimated artefact period: 16.0002
# Sample : 1925 | Estimated artefact period: 16.0002
# Sample : 1926 | Estimated artefact period: 16.0001
# Sample : 1927 | Estimated artefact period: 16.0002
# Sample : 1928 | Estimated artefact period: 16.0002
# Sample : 1929 | Estimated artefact period: 16.0002
# Sample : 1930 | Estimated artefact period: 16.0002
# Sample : 1931 | Estimated artefact period: 16.0002
# Sample : 1932 | Estimated artefact period: 16.0003
# Sample : 1933 | Estimated artefact period: 16.0001
# Sample : 1934 | Estimated artefact period: 16.0001
# Sample : 1935 | Estimated artefact period: 16.0002
# Sample : 1936 | Estimated artefact period: 16.0001
# Sample : 1937 | Estimated artefact period: 16.0002
# Sample : 1938 | Estimated artefact period: 16.0001
# Sample : 1939 | Estimated artefact period: 16.0002
# Sample : 1940 | Estimated artefact period: 16.0001
# Sample : 1941 | Estimated artefact period: 16.0001
# Sample : 1942 | Estimated artefact period: 16.0002
# Sample : 1943 | Estimated artefact period: 16.0001
# Sample : 1944 | Estimated artefact period: 16.0001
# Sample : 1945 | Estimated artefact period: 16.0001
# Sample : 1946 | Estimated artefact period: 16.0002
# Sample : 1947 | Estimated artefact period: 16.0002
# Sample : 1948 | Estimated artefact period: 16.0002
# Sample : 1949 | Estimated artefact period: 16.0001
# Sample : 1950 | Estimated artefact period: 16.0001
# Sample : 1951 | Estimated artefact period: 16.0001
# Sample : 1952 | Estimated artefact period: 16.0001
# Sample : 1953 | Estimated artefact period: 16.0002
# Sample : 1954 | Estimated artefact period: 16.0001
# Sample : 1955 | Estimated artefact period: 16.0001
# Sample : 1956 | Estimated artefact period: 16.0001
# Sample : 1957 | Estimated artefact period: 16.0001
# Sample : 1958 | Estimated artefact period: 16.0001
# Sample : 1959 | Estimated artefact period: 16.0002
# Sample : 1960 | Estimated artefact period: 16.0001
# Sample : 1961 | Estimated artefact period: 16.0002
# Sample : 1962 | Estimated artefact period: 16.0001
# Sample : 1963 | Estimated artefact period: 16.0001
# Sample : 1964 | Estimated artefact period: 16.0001
# Sample : 1965 | Estimated artefact period: 16.0002
# Sample : 1966 | Estimated artefact period: 16.0002
# Sample : 1967 | Estimated artefact period: 16.0001
# Sample : 1968 | Estimated artefact period: 16.0002
# Sample : 1969 | Estimated artefact period: 16.0002
# Sample : 1970 | Estimated artefact period: 16.0001
# Sample : 1971 | Estimated artefact period: 16.0001
# Sample : 1972 | Estimated artefact period: 16.0001
# Sample : 1973 | Estimated artefact period: 16.0002
# Sample : 1974 | Estimated artefact period: 16.0002
# Sample : 1975 | Estimated artefact period: 16.0002
# Sample : 1976 | Estimated artefact period: 16.0002
# Sample : 1977 | Estimated artefact period: 16.0002
# Sample : 1978 | Estimated artefact period: 16.0001
# Sample : 1979 | Estimated artefact period: 16.0001
# Sample : 1980 | Estimated artefact period: 16.0001
# Sample : 1981 | Estimated artefact period: 16.0001
# Sample : 1982 | Estimated artefact period: 16.0002
# Sample : 1983 | Estimated artefact period: 16.0002
# Sample : 1984 | Estimated artefact period: 16.0002
# Sample : 1985 | Estimated artefact period: 16.0001
# Sample : 1986 | Estimated artefact period: 16.0002
# Sample : 1987 | Estimated artefact period: 16.0002
# Sample : 1988 | Estimated artefact period: 16.0002
# Sample : 1989 | Estimated artefact period: 16.0002
# Sample : 1990 | Estimated artefact period: 16.0002
# Sample : 1991 | Estimated artefact period: 16.0001
# Sample : 1992 | Estimated artefact period: 16.0001
# Sample : 1993 | Estimated artefact period: 16.0002
# Sample : 1994 | Estimated artefact period: 16.0001
# Sample : 1995 | Estimated artefact period: 16.0002
# Sample : 1996 | Estimated artefact period: 16.0001
# Sample : 1997 | Estimated artefact period: 16.0002
# Sample : 1998 | Estimated artefact period: 16.0002
# Sample : 1999 | Estimated artefact period: 16.0001

# %%
# save_path = '../../../../result/paper/'
# save_title = 'PARRM'
Result_Plot(Contaminated, parrmed_data, Clean)
# Result_Plot_paper(Contaminated, parrmed_data, Clean, save_path, save_title)
# Out:
# < MSE >
# Time Domain MSE: 39.67562694825124 ± 0.0
# Frequency Domain MSE: 217764.62149414196 ± 0.0
# Time + Frequency MSE: 12724.289574846123 ± 0.0
