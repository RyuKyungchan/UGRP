# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('../../../tool_code/python_tool_code/function/') # "~~/tool_code/plot/" (상대 경로)
sys.path.append('../../../tool_code/python_tool_code/frequency_analysis/frequency_func')

import DataPlot

# %%
# 데이터 load & plot
datapath='../../../result/output_data/'
# Data_Load_Plot을 사용하지 않고 load data
Contaminated_data, SACed_data, Clean_data = np.load(datapath+'model_output.npy')

# %%
save_path = '../../../result/CNN/'
save_title = 'CNN'

DataPlot.Result_Plot_paper(Contaminated_data, SACed_data, Clean_data)
# Out:
# < MSE >
# Time Domain MSE: 0.05682237758329146 ± 0.006205735315644589
# Frequency Domain MSE: 2.909747590508524 ± 1.1275293813709502
